# %% [markdown]
# Let's see what our models have managed to learn:

# %%
from generate import generate_unconditionally, generate_conditionally

# %%
generate_unconditionally()

# %%
generate_conditionally('welcome to lyrebird')
